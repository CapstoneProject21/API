# %%
#!pip install requests

# %%
import requests
import datetime
from urllib.parse import urlencode
import json
import spotipy
import spotipy.util as util

# %%
import base64

# %%
client_id = '9ec14c18b8114a569770be752b524b7e'
client_secret = '6d13d61e65a2418697e225936274c7bf'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    auth_token= "https://accounts.spotify.com/api/token"
    
    def __init__(self, client_id, client_secret, *args,**kwargs):
        super().__init__(*args,**kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
    
    def get_client_credentials(self):
        """returns a base64 encoded string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None:
            raise Exception("You must set client_id and client_secret")
        client_cred = f"{client_id}:{client_secret}"
        client_cred_b64 = base64.b64encode(client_cred.encode())
        return client_cred_b64.decode()
        
    def get_token_header(self):
        client_cred_b64 = self.get_client_credentials()
        return{
             "Authorization" : f"Basic {client_cred_b64}"
        }
    def get_token_data(self):
        return{
            "grant_type": "client_credentials"
        }
    
    def Authorization(self):
        auth_token = self.auth_token
        token_data = self.get_token_data()
        token_header = self.get_token_header()
        r = requests.post(auth_token,data=token_data, headers=token_header)
        if r.status_code not in range(200,299):
            raise Exception("could not authenticate client")
            #return False
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.Authorization()
            return self.get_access_token()
        elif token == None:
            return self.get_access_token()
        return token
    
    def get_resources_header(self):
        access_token = self.get_access_token()
        header = {
            "Authorization": f"Bearer {access_token}"
        }
        return header
    
    def get_resources(self, _id, resource_type="album", version='v1'):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{_id}"
        header = self.get_resources_header()
        r = requests.get(endpoint, headers=header)
        if r.status_code not in range(200,299):
            return{}
        return r.json()
    
    def get_album(self,_id):
        return self.get_resources(_id,resource_type='albums')
    
    def get_artist(self,_id):
        return self.get_resources(_id,resource_type='artists')
    
    def get_artist_albums(self,_id):
        return self.get_resources(_id,resource_type='artist_albums')

    def get_track(self,_id):
        return self.get_resources(_id,resource_type='tracks')
    
    
    def base_search(self, query_parameters, search_type='artists'):
        access_token = self.get_access_token()
        header = {
            "Authorization": f"Bearer {access_token}"
        }
        endpoint = "https://api.spotify.com/v1/search"
        lookup_url = f"{endpoint}?{query_parameters}"
        r = requests.get(lookup_url, headers=header)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
        
    def search(self,query= None, operator=None, operator_query=None,search_type='artist'):
        if query == None:
            raise Exception('Query Required')
        if isinstance(query,dict):
            query = " ".join([f"{k}:{v}" for k,v in query.items()])
        if operator !=None and operator_query !=None:
            if operator.lower() =="or" or operator.lower() =="not":
                operator = operator.upper()
            if isinstance(operator_query,str):
                query= f"{query}{operator}{operator_query}"
        query_parameters = urlencode({"q": query, "type": search_type.lower()})
        print(query_parameters)
        return self.base_search(query_parameters)

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
#finding artist
searchQuery = input("Search: ")
#print()
searchResult = spotify.search(searchQuery,"artist")
print(json.dumps(searchResult, sort_keys=True, indent=4))
# Out:
# q=pink+flyod&type=artist
# {
#     "artists": {
#         "href": "https://api.spotify.com/v1/search?query=pink+flyod&type=artist&offset=0&limit=20",
#         "items": [
#             {
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/artist/0k17h0D3J5VfsdmQ1iZtE9"
#                 },
#                 "followers": {
#                     "href": null,
#                     "total": 15587170
#                 },
#                 "genres": [
#                     "album rock",
#                     "art rock",
#                     "classic rock",
#                     "progressive rock",
#                     "psychedelic rock",
#                     "rock",
#                     "symphonic rock"
#                 ],
#                 "href": "https://api.spotify.com/v1/artists/0k17h0D3J5VfsdmQ1iZtE9",
#                 "id": "0k17h0D3J5VfsdmQ1iZtE9",
#                 "images": [
#                     {
#                         "height": 977,
#                         "url": "https://i.scdn.co/image/e69f71e2be4b67b82af90fb8e9d805715e0684fa",
#                         "width": 1000
#                     },
#                     {
#                         "height": 625,
#                         "url": "https://i.scdn.co/image/d011c95081cd9a329e506abd7ded47535d524a07",
#                         "width": 640
#                     },
#                     {
#                         "height": 195,
#                         "url": "https://i.scdn.co/image/f0a39a8a196a87a7236bdcf8a8708f6d5d3547cc",
#                         "width": 200
#                     },
#                     {
#                         "height": 63,
#                         "url": "https://i.scdn.co/image/ec1fb7127168dbaa962404031409c5a293b95ec6",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Pink Floyd",
#                 "popularity": 81,
#                 "type": "artist",
#                 "uri": "spotify:artist:0k17h0D3J5VfsdmQ1iZtE9"
#             },
#             {
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/artist/4Kqp4AtoCDoCotN7KjrLKL"
#                 },
#                 "followers": {
#                     "href": null,
#                     "total": 984
#                 },
#                 "genres": [],
#                 "href": "https://api.spotify.com/v1/artists/4Kqp4AtoCDoCotN7KjrLKL",
#                 "id": "4Kqp4AtoCDoCotN7KjrLKL",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b273c53cafd11f6fe338cf5ea13e",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e02c53cafd11f6fe338cf5ea13e",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d00004851c53cafd11f6fe338cf5ea13e",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Pink Floyd History",
#                 "popularity": 16,
#                 "type": "artist",
#                 "uri": "spotify:artist:4Kqp4AtoCDoCotN7KjrLKL"
#             },
#             {
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/artist/78uKGJK3DfcAYJHQg6bI7h"
#                 },
#                 "followers": {
#                     "href": null,
#                     "total": 53
#                 },
#                 "genres": [],
#                 "href": "https://api.spotify.com/v1/artists/78uKGJK3DfcAYJHQg6bI7h",
#                 "id": "78uKGJK3DfcAYJHQg6bI7h",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b27355b4b8a48216a0a0732064c4",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e0255b4b8a48216a0a0732064c4",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d0000485155b4b8a48216a0a0732064c4",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Floyd Pink & The Punks",
#                 "popularity": 0,
#                 "type": "artist",
#                 "uri": "spotify:artist:78uKGJK3DfcAYJHQg6bI7h"
#             },
#             {
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/artist/0hioiM0MDloPdLjTE86zz8"
#                 },
#                 "followers": {
#                     "href": null,
#                     "total": 4732
#                 },
#                 "genres": [],
#                 "href": "https://api.spotify.com/v1/artists/0hioiM0MDloPdLjTE86zz8",
#                 "id": "0hioiM0MDloPdLjTE86zz8",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b273566c25dfbf750226f2d3cce1",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e02566c25dfbf750226f2d3cce1",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d00004851566c25dfbf750226f2d3cce1",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Pink Floyd Redux",
#                 "popularity": 21,
#                 "type": "artist",
#                 "uri": "spotify:artist:0hioiM0MDloPdLjTE86zz8"
#             },
#             {
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/artist/6QvBTZOpVhDqw3qFeBagCa"
#                 },
#                 "followers": {
#                     "href": null,
#                     "total": 5583
#                 },
#                 "genres": [],
#                 "href": "https://api.spotify.com/v1/artists/6QvBTZOpVhDqw3qFeBagCa",
#                 "id": "6QvBTZOpVhDqw3qFeBagCa",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b273b6c1178d7f41f48160729c88",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e02b6c1178d7f41f48160729c88",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d00004851b6c1178d7f41f48160729c88",
#                         "width": 64
#                     }
#                 ],
#                 "name": "The Australian Pink Floyd Show",
#                 "popularity": 17,
#                 "type": "artist",
#                 "uri": "spotify:artist:6QvBTZOpVhDqw3qFeBagCa"
#             },
#             {
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/artist/3QDOgSJUxeDUSroVZqechK"
#                 },
#                 "followers": {
#                     "href": null,
#                     "total": 657
#                 },
#                 "genres": [],
#                 "href": "https://api.spotify.com/v1/artists/3QDOgSJUxeDUSroVZqechK",
#                 "id": "3QDOgSJUxeDUSroVZqechK",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab6761610000e5ebf26c661650fa951cc95e6fec",
#                         "width": 640
#                     },
#                     {
#                         "height": 320,
#                         "url": "https://i.scdn.co/image/ab67616100005174f26c661650fa951cc95e6fec",
#                         "width": 320
#                     },
#                     {
#                         "height": 160,
#                         "url": "https://i.scdn.co/image/ab6761610000f178f26c661650fa951cc95e6fec",
#                         "width": 160
#                     }
#                 ],
#                 "name": "THE ILLUSION A SOUND LIKE PINK FLOYD",
#                 "popularity": 17,
#                 "type": "artist",
#                 "uri": "spotify:artist:3QDOgSJUxeDUSroVZqechK"
#             },
#             {
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/artist/2p8RD57F5dwDzIDZ95k3h0"
#                 },
#                 "followers": {
#                     "href": null,
#                     "total": 2565
#                 },
#                 "genres": [],
#                 "href": "https://api.spotify.com/v1/artists/2p8RD57F5dwDzIDZ95k3h0",
#                 "id": "2p8RD57F5dwDzIDZ95k3h0",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b2736453bd4ef0f9900337022505",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e026453bd4ef0f9900337022505",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d000048516453bd4ef0f9900337022505",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Celtic Pink Floyd",
#                 "popularity": 11,
#                 "type": "artist",
#                 "uri": "spotify:artist:2p8RD57F5dwDzIDZ95k3h0"
#             },
#             {
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/artist/2tDvdcTW7H4vYW7S18MA2e"
#                 },
#                 "followers": {
#                     "href": null,
#                     "total": 3472
#                 },
#                 "genres": [],
#                 "href": "https://api.spotify.com/v1/artists/2tDvdcTW7H4vYW7S18MA2e",
#                 "id": "2tDvdcTW7H4vYW7S18MA2e",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b273e5fda56f522e2e88befc20d5",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e02e5fda56f522e2e88befc20d5",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d00004851e5fda56f522e2e88befc20d5",
#                         "width": 64
#                     }
#                 ],
#                 "name": "The Pink Floyd Story",
#                 "popularity": 13,
#                 "type": "artist",
#                 "uri": "spotify:artist:2tDvdcTW7H4vYW7S18MA2e"
#             },
#             {
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/artist/6ZrAKNMggJBcFcncgOG7ig"
#                 },
#                 "followers": {
#                     "href": null,
#                     "total": 435
#                 },
#                 "genres": [],
#                 "href": "https://api.spotify.com/v1/artists/6ZrAKNMggJBcFcncgOG7ig",
#                 "id": "6ZrAKNMggJBcFcncgOG7ig",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b273f72d1ea66cca52a66ced6dc8",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e02f72d1ea66cca52a66ced6dc8",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d00004851f72d1ea66cca52a66ced6dc8",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Floyd Pink",
#                 "popularity": 0,
#                 "type": "artist",
#                 "uri": "spotify:artist:6ZrAKNMggJBcFcncgOG7ig"
#             },
#             {
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/artist/0hdBO1QbB63ixZNRBFD0K9"
#                 },
#                 "followers": {
#                     "href": null,
#                     "total": 969
#                 },
#                 "genres": [],
#                 "href": "https://api.spotify.com/v1/artists/0hdBO1QbB63ixZNRBFD0K9",
#                 "id": "0hdBO1QbB63ixZNRBFD0K9",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b273f22dce385a0cb9369d196c25",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e02f22dce385a0cb9369d196c25",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d00004851f22dce385a0cb9369d196c25",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Pink Floyd Project",
#                 "popularity": 7,
#                 "type": "artist",
#                 "uri": "spotify:artist:0hdBO1QbB63ixZNRBFD0K9"
#             },
#             {
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/artist/5KlZxm5ILJ9tuGRG74b6vw"
#                 },
#                 "followers": {
#                     "href": null,
#                     "total": 495
#                 },
#                 "genres": [],
#                 "href": "https://api.spotify.com/v1/artists/5KlZxm5ILJ9tuGRG74b6vw",
#                 "id": "5KlZxm5ILJ9tuGRG74b6vw",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b273fecc4b36a7114fe909809bf6",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e02fecc4b36a7114fe909809bf6",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d00004851fecc4b36a7114fe909809bf6",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Atom Pink Floyd Tribute",
#                 "popularity": 8,
#                 "type": "artist",
#                 "uri": "spotify:artist:5KlZxm5ILJ9tuGRG74b6vw"
#             },
#             {
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/artist/77hVxSyFhrS6zEzSuk7TQI"
#                 },
#                 "followers": {
#                     "href": null,
#                     "total": 280
#                 },
#                 "genres": [],
#                 "href": "https://api.spotify.com/v1/artists/77hVxSyFhrS6zEzSuk7TQI",
#                 "id": "77hVxSyFhrS6zEzSuk7TQI",
#                 "images": [],
#                 "name": "Pink Floyd Tribute Band",
#                 "popularity": 13,
#                 "type": "artist",
#                 "uri": "spotify:artist:77hVxSyFhrS6zEzSuk7TQI"
#             },
#             {
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/artist/3gqUPw8iF25or96s2jaFAU"
#                 },
#                 "followers": {
#                     "href": null,
#                     "total": 296
#                 },
#                 "genres": [],
#                 "href": "https://api.spotify.com/v1/artists/3gqUPw8iF25or96s2jaFAU",
#                 "id": "3gqUPw8iF25or96s2jaFAU",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b2737a01a32fb0f93821f4648fee",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e027a01a32fb0f93821f4648fee",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d000048517a01a32fb0f93821f4648fee",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Hungarian Pink Floyd Show",
#                 "popularity": 3,
#                 "type": "artist",
#                 "uri": "spotify:artist:3gqUPw8iF25or96s2jaFAU"
#             },
#             {
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/artist/5wRc6n7PewBiHPjkWSoCSk"
#                 },
#                 "followers": {
#                     "href": null,
#                     "total": 636
#                 },
#                 "genres": [],
#                 "href": "https://api.spotify.com/v1/artists/5wRc6n7PewBiHPjkWSoCSk",
#                 "id": "5wRc6n7PewBiHPjkWSoCSk",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b273385d0ec266d9f6d1dd5b67c9",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e02385d0ec266d9f6d1dd5b67c9",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d00004851385d0ec266d9f6d1dd5b67c9",
#                         "width": 64
#                     }
#                 ],
#                 "name": "The Machine Perform Pink Floyd",
#                 "popularity": 14,
#                 "type": "artist",
#                 "uri": "spotify:artist:5wRc6n7PewBiHPjkWSoCSk"
#             },
#             {
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/artist/2OsLsO9Zygms3SrR8JkA7B"
#                 },
#                 "followers": {
#                     "href": null,
#                     "total": 88
#                 },
#                 "genres": [],
#                 "href": "https://api.spotify.com/v1/artists/2OsLsO9Zygms3SrR8JkA7B",
#                 "id": "2OsLsO9Zygms3SrR8JkA7B",
#                 "images": [],
#                 "name": "Made famous by Pink Floyd",
#                 "popularity": 0,
#                 "type": "artist",
#                 "uri": "spotify:artist:2OsLsO9Zygms3SrR8JkA7B"
#             }
#         ],
#         "limit": 20,
#         "next": null,
#         "offset": 0,
#         "previous": null,
#         "total": 15
#     }
# }

# %%
#artist details
artist = searchResult['artists']['items'][0]
print("Artist Name: " + (artist['name']))
print("Artist Follower: " + (str(artist['followers']['total']) + " followers"))
print("Artist Genres: " + (str(artist['genres'])))
print()
artistID = artist['id']
#print(artistID)
#webbrowser.open(artist['images'][0]['url'])

"""
album and tracks of artist
trackURIs = []
trackArt = []
"""
i = 0

#Scraping album info


albumResult = spotify.search(artistID)
print(json.dumps(albumResult, sort_keys=True, indent=4))


#albumResult = albumResult['items']

"""
for item in albumResult:
    print("Album" + item['name'])
    albumID = item['id']
    #albumArt = item['images'][0]['uri]

    #Albums have tracks[scraping track data]
    trackResult = spotify.get_track(albumID)
    trackResult = trackResult['items']

    for item in trackResult:
        print(str(i) + ":" + item['name'])
        trackURIs.append(item['uri'])
        #trackArt.append(albumArt)
        i+=1
    print()
"""
# Out:
# Artist Name: Pink Floyd
# Artist Follower: 15587170 followers
# Artist Genres: ['album rock', 'art rock', 'classic rock', 'progressive rock', 'psychedelic rock', 'rock', 'symphonic rock']
#
# q=0k17h0D3J5VfsdmQ1iZtE9&type=artist
# {
#     "artists": {
#         "href": "https://api.spotify.com/v1/search?query=0k17h0D3J5VfsdmQ1iZtE9&type=artist&offset=0&limit=20",
#         "items": [],
#         "limit": 20,
#         "next": null,
#         "offset": 0,
#         "previous": null,
#         "total": 0
#     }
# }
# '\nfor item in albumResult:\n    print("Album" + item[\'name\'])\n    albumID = item[\'id\']\n    #albumArt = item[\'images\'][0][\'uri]\n\n    #Albums have tracks[scraping track data]\n    trackResult = spotify.get_track(albumID)\n    trackResult = trackResult[\'items\']\n\n    for item in trackResult:\n        print(str(i) + ":" + item[\'name\'])\n        trackURIs.append(item[\'uri\'])\n        #trackArt.append(albumArt)\n        i+=1\n    print()\n'

# %%
spotify.search({"album": "Ye","artist":"Kanye"}, search_type="track")
# Out:
# q=album%3AYe+artist%3AKanye&type=track
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=album%3AYe+artist%3AKanye&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#        'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#        'id': '5K4W6rqBFWDnAN6FQUkS6x',
#        'name': 'Kanye West',
#        'type': 'artist',
#        'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7D2NdGvBHIavgLhmcwhluK'},
#      'href': 'https://api.spotify.com/v1/albums/7D2NdGvBHIavgLhmcwhluK',
#      'id': '7D2NdGvBHIavgLhmcwhluK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731dacfbc31cc873d132958af9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021dacfbc31cc873d132958af9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511dacfbc31cc873d132958af9',
#        'width': 64}],
#      'name': 'Yeezus',
#      'release_date': '2013-06-18',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:7D2NdGvBHIavgLhmcwhluK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#       'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#       'id': '5K4W6rqBFWDnAN6FQUkS6x',
#       'name': 'Kanye West',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 229146,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71307523'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3sNVsP50132BTNlImLx70i'},
#     'href': 'https://api.spotify.com/v1/tracks/3sNVsP50132BTNlImLx70i',
#     'id': '3sNVsP50132BTNlImLx70i',
#     'is_local': False,
#     'name': 'Bound 2',
#     'popularity': 80,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:3sNVsP50132BTNlImLx70i'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#        'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#        'id': '5K4W6rqBFWDnAN6FQUkS6x',
#        'name': 'Kanye West',
#        'type': 'artist',
#        'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Ek1q2haOnxVqhvVKqMvJe'},
#      'href': 'https://api.spotify.com/v1/albums/2Ek1q2haOnxVqhvVKqMvJe',
#      'id': '2Ek1q2haOnxVqhvVKqMvJe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730cd942c1a864afa4e92d04f2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020cd942c1a864afa4e92d04f2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510cd942c1a864afa4e92d04f2',
#        'width': 64}],
#      'name': 'ye',
#      'release_date': '2018-06-01',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:2Ek1q2haOnxVqhvVKqMvJe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#       'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#       'id': '5K4W6rqBFWDnAN6FQUkS6x',
#       'name': 'Kanye West',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2HPaUgqeutzr3jx5a9WyDV'},
#       'href': 'https://api.spotify.com/v1/artists/2HPaUgqeutzr3jx5a9WyDV',
#       'id': '2HPaUgqeutzr3jx5a9WyDV',
#       'name': 'PARTYNEXTDOOR',
#       'type': 'artist',
#       'uri': 'spotify:artist:2HPaUgqeutzr3jx5a9WyDV'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 271386,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71807761'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7vgTNTaEz3CsBZ1N4YQalM'},
#     'href': 'https://api.spotify.com/v1/tracks/7vgTNTaEz3CsBZ1N4YQalM',
#     'id': '7vgTNTaEz3CsBZ1N4YQalM',
#     'is_local': False,
#     'name': 'Ghost Town',
#     'popularity': 77,
#     'preview_url': None,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:7vgTNTaEz3CsBZ1N4YQalM'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#        'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#        'id': '5K4W6rqBFWDnAN6FQUkS6x',
#        'name': 'Kanye West',
#        'type': 'artist',
#        'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Ek1q2haOnxVqhvVKqMvJe'},
#      'href': 'https://api.spotify.com/v1/albums/2Ek1q2haOnxVqhvVKqMvJe',
#      'id': '2Ek1q2haOnxVqhvVKqMvJe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730cd942c1a864afa4e92d04f2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020cd942c1a864afa4e92d04f2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510cd942c1a864afa4e92d04f2',
#        'width': 64}],
#      'name': 'ye',
#      'release_date': '2018-06-01',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:2Ek1q2haOnxVqhvVKqMvJe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#       'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#       'id': '5K4W6rqBFWDnAN6FQUkS6x',
#       'name': 'Kanye West',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 215320,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71807795'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3s7MCdXyWmwjdcWh7GWXas'},
#     'href': 'https://api.spotify.com/v1/tracks/3s7MCdXyWmwjdcWh7GWXas',
#     'id': '3s7MCdXyWmwjdcWh7GWXas',
#     'is_local': False,
#     'name': 'Violent Crimes',
#     'popularity': 76,
#     'preview_url': None,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:3s7MCdXyWmwjdcWh7GWXas'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#        'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#        'id': '5K4W6rqBFWDnAN6FQUkS6x',
#        'name': 'Kanye West',
#        'type': 'artist',
#        'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Ek1q2haOnxVqhvVKqMvJe'},
#      'href': 'https://api.spotify.com/v1/albums/2Ek1q2haOnxVqhvVKqMvJe',
#      'id': '2Ek1q2haOnxVqhvVKqMvJe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730cd942c1a864afa4e92d04f2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020cd942c1a864afa4e92d04f2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510cd942c1a864afa4e92d04f2',
#        'width': 64}],
#      'name': 'ye',
#      'release_date': '2018-06-01',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:2Ek1q2haOnxVqhvVKqMvJe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#       'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#       'id': '5K4W6rqBFWDnAN6FQUkS6x',
#       'name': 'Kanye West',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 145506,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71807681'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3U21A07gAloCc4P7J8rxcn'},
#     'href': 'https://api.spotify.com/v1/tracks/3U21A07gAloCc4P7J8rxcn',
#     'id': '3U21A07gAloCc4P7J8rxcn',
#     'is_local': False,
#     'name': 'All Mine',
#     'popularity': 75,
#     'preview_url': None,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3U21A07gAloCc4P7J8rxcn'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#        'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#        'id': '5K4W6rqBFWDnAN6FQUkS6x',
#        'name': 'Kanye West',
#        'type': 'artist',
#        'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7D2NdGvBHIavgLhmcwhluK'},
#      'href': 'https://api.spotify.com/v1/albums/7D2NdGvBHIavgLhmcwhluK',
#      'id': '7D2NdGvBHIavgLhmcwhluK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731dacfbc31cc873d132958af9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021dacfbc31cc873d132958af9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511dacfbc31cc873d132958af9',
#        'width': 64}],
#      'name': 'Yeezus',
#      'release_date': '2013-06-18',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:7D2NdGvBHIavgLhmcwhluK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#       'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#       'id': '5K4W6rqBFWDnAN6FQUkS6x',
#       'name': 'Kanye West',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 188013,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71307719'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/722tgOgdIbNe3BEyLnejw4'},
#     'href': 'https://api.spotify.com/v1/tracks/722tgOgdIbNe3BEyLnejw4',
#     'id': '722tgOgdIbNe3BEyLnejw4',
#     'is_local': False,
#     'name': 'Black Skinhead',
#     'popularity': 76,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:722tgOgdIbNe3BEyLnejw4'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#        'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#        'id': '5K4W6rqBFWDnAN6FQUkS6x',
#        'name': 'Kanye West',
#        'type': 'artist',
#        'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7D2NdGvBHIavgLhmcwhluK'},
#      'href': 'https://api.spotify.com/v1/albums/7D2NdGvBHIavgLhmcwhluK',
#      'id': '7D2NdGvBHIavgLhmcwhluK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731dacfbc31cc873d132958af9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021dacfbc31cc873d132958af9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511dacfbc31cc873d132958af9',
#        'width': 64}],
#      'name': 'Yeezus',
#      'release_date': '2013-06-18',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:7D2NdGvBHIavgLhmcwhluK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#       'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#       'id': '5K4W6rqBFWDnAN6FQUkS6x',
#       'name': 'Kanye West',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 359800,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71307498'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/42GcjriRK6srwHkfbkBqVl'},
#     'href': 'https://api.spotify.com/v1/tracks/42GcjriRK6srwHkfbkBqVl',
#     'id': '42GcjriRK6srwHkfbkBqVl',
#     'is_local': False,
#     'name': 'Blood On The Leaves',
#     'popularity': 68,
#     'preview_url': None,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:42GcjriRK6srwHkfbkBqVl'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#        'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#        'id': '5K4W6rqBFWDnAN6FQUkS6x',
#        'name': 'Kanye West',
#        'type': 'artist',
#        'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Ek1q2haOnxVqhvVKqMvJe'},
#      'href': 'https://api.spotify.com/v1/albums/2Ek1q2haOnxVqhvVKqMvJe',
#      'id': '2Ek1q2haOnxVqhvVKqMvJe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730cd942c1a864afa4e92d04f2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020cd942c1a864afa4e92d04f2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510cd942c1a864afa4e92d04f2',
#        'width': 64}],
#      'name': 'ye',
#      'release_date': '2018-06-01',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:2Ek1q2haOnxVqhvVKqMvJe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#       'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#       'id': '5K4W6rqBFWDnAN6FQUkS6x',
#       'name': 'Kanye West',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 188773,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71807679'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1qsHYUd2c1wFGcn7e63QmG'},
#     'href': 'https://api.spotify.com/v1/tracks/1qsHYUd2c1wFGcn7e63QmG',
#     'id': '1qsHYUd2c1wFGcn7e63QmG',
#     'is_local': False,
#     'name': 'Yikes',
#     'popularity': 67,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1qsHYUd2c1wFGcn7e63QmG'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#        'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#        'id': '5K4W6rqBFWDnAN6FQUkS6x',
#        'name': 'Kanye West',
#        'type': 'artist',
#        'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7D2NdGvBHIavgLhmcwhluK'},
#      'href': 'https://api.spotify.com/v1/albums/7D2NdGvBHIavgLhmcwhluK',
#      'id': '7D2NdGvBHIavgLhmcwhluK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731dacfbc31cc873d132958af9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021dacfbc31cc873d132958af9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511dacfbc31cc873d132958af9',
#        'width': 64}],
#      'name': 'Yeezus',
#      'release_date': '2013-06-18',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:7D2NdGvBHIavgLhmcwhluK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#       'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#       'id': '5K4W6rqBFWDnAN6FQUkS6x',
#       'name': 'Kanye West',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
# ...
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 178040,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71307511'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3RKblQNJs8HPvWBgXmq6nn'},
#     'href': 'https://api.spotify.com/v1/tracks/3RKblQNJs8HPvWBgXmq6nn',
#     'id': '3RKblQNJs8HPvWBgXmq6nn',
#     'is_local': False,
#     'name': 'Send It Up',
#     'popularity': 58,
#     'preview_url': None,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:3RKblQNJs8HPvWBgXmq6nn'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#        'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#        'id': '5K4W6rqBFWDnAN6FQUkS6x',
#        'name': 'Kanye West',
#        'type': 'artist',
#        'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1PkFK7nfqX9jEMaIA8O12Y'},
#      'href': 'https://api.spotify.com/v1/albums/1PkFK7nfqX9jEMaIA8O12Y',
#      'id': '1PkFK7nfqX9jEMaIA8O12Y',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732ec3a83efc834b752df73884',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022ec3a83efc834b752df73884',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512ec3a83efc834b752df73884',
#        'width': 64}],
#      'name': 'Ye vs. the People (starring TI as the People)',
#      'release_date': '2018-04-28',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1PkFK7nfqX9jEMaIA8O12Y'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#       'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#       'id': '5K4W6rqBFWDnAN6FQUkS6x',
#       'name': 'Kanye West',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 202641,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71806072'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/69b0SDYOymaqYwm3la237H'},
#     'href': 'https://api.spotify.com/v1/tracks/69b0SDYOymaqYwm3la237H',
#     'id': '69b0SDYOymaqYwm3la237H',
#     'is_local': False,
#     'name': 'Ye vs. the People (starring TI as the People)',
#     'popularity': 42,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:69b0SDYOymaqYwm3la237H'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#        'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#        'id': '5K4W6rqBFWDnAN6FQUkS6x',
#        'name': 'Kanye West',
#        'type': 'artist',
#        'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#      'available_markets': ['AE',
#       'BB',
#       'BF',
#       'BH',
#       'BN',
#       'BY',
#       'CA',
#       'DZ',
#       'EG',
#       'GB',
#       'GH',
#       'ID',
#       'IE',
#       'IN',
#       'JO',
#       'KG',
#       'KR',
#       'KW',
#       'KZ',
#       'LB',
#       'MA',
#       'MX',
#       'MY',
#       'NP',
#       'OM',
#       'PS',
#       'QA',
#       'RU',
#       'SA',
#       'SG',
#       'TD',
#       'TN',
#       'TR',
#       'UA',
#       'US',
#       'UZ'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0zepz9d3dDgoEE8Rzjs8G2'},
#      'href': 'https://api.spotify.com/v1/albums/0zepz9d3dDgoEE8Rzjs8G2',
#      'id': '0zepz9d3dDgoEE8Rzjs8G2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27361ebab9aeb8e03547c9ee3b1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0261ebab9aeb8e03547c9ee3b1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485161ebab9aeb8e03547c9ee3b1',
#        'width': 64}],
#      'name': 'Ye vs. the People (starring TI as the People)',
#      'release_date': '2018-04-27',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0zepz9d3dDgoEE8Rzjs8G2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#       'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#       'id': '5K4W6rqBFWDnAN6FQUkS6x',
#       'name': 'Kanye West',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#     'available_markets': ['AE',
#      'BB',
#      'BF',
#      'BH',
#      'BN',
#      'BY',
#      'CA',
#      'DZ',
#      'EG',
#      'GB',
#      'GH',
#      'ID',
#      'IE',
#      'IN',
#      'JO',
#      'KG',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'MA',
#      'MX',
#      'MY',
#      'NP',
#      'OM',
#      'PS',
#      'QA',
#      'RU',
#      'SA',
#      'SG',
#      'TD',
#      'TN',
#      'TR',
#      'UA',
#      'US',
#      'UZ'],
#     'disc_number': 1,
#     'duration_ms': 202641,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71806073'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3SgxTQVywhDVAVhMhhfbCl'},
#     'href': 'https://api.spotify.com/v1/tracks/3SgxTQVywhDVAVhMhhfbCl',
#     'id': '3SgxTQVywhDVAVhMhhfbCl',
#     'is_local': False,
#     'name': 'Ye vs. the People (starring TI as the People)',
#     'popularity': 13,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3SgxTQVywhDVAVhMhhfbCl'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Idwl1KH1heUMtkQJAnuxq'},
#        'href': 'https://api.spotify.com/v1/artists/6Idwl1KH1heUMtkQJAnuxq',
#        'id': '6Idwl1KH1heUMtkQJAnuxq',
#        'name': 'KING KANYEMBI',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Idwl1KH1heUMtkQJAnuxq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5dr7Ji6uLj3bKOIgxSvqLo'},
#      'href': 'https://api.spotify.com/v1/albums/5dr7Ji6uLj3bKOIgxSvqLo',
#      'id': '5dr7Ji6uLj3bKOIgxSvqLo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a64f0512b7b1b4e854642297',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a64f0512b7b1b4e854642297',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a64f0512b7b1b4e854642297',
#        'width': 64}],
#      'name': 'The Lonely Years',
#      'release_date': '2019-11-29',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5dr7Ji6uLj3bKOIgxSvqLo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Idwl1KH1heUMtkQJAnuxq'},
#       'href': 'https://api.spotify.com/v1/artists/6Idwl1KH1heUMtkQJAnuxq',
#       'id': '6Idwl1KH1heUMtkQJAnuxq',
#       'name': 'KING KANYEMBI',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Idwl1KH1heUMtkQJAnuxq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 211941,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZ93L1970338'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/72zGFbLNuz7KJYlhJnPOme'},
#     'href': 'https://api.spotify.com/v1/tracks/72zGFbLNuz7KJYlhJnPOme',
#     'id': '72zGFbLNuz7KJYlhJnPOme',
#     'is_local': False,
#     'name': 'The Lonely Years',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/96e89a06cd2b9eaf2eb0c35469a51eab720bacf3?cid=9ec14c18b8114a569770be752b524b7e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:72zGFbLNuz7KJYlhJnPOme'}],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 20}}

# %%
#spotify.get_artist("5K4W6rqBFWDnAN6FQUkS6x")

# %%
spotify.get_album("4UlGauD7ROb3YbVOFMgW5u")
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#    'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#    'id': '5pKCCKE2ajJHZ9KAiaK11H',
#    'name': 'Rihanna',
#    'type': 'artist',
#    'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RU',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'copyrights': [{'text': '© 2016 Westbury Road Entertainment. Distributed by Roc Nation Records',
#    'type': 'C'},
#   {'text': '℗ 2016 Westbury Road Entertainment. Distributed by Roc Nation Records',
#    'type': 'P'}],
#  'external_ids': {'upc': '00851365006554'},
#  'external_urls': {'spotify': 'https://open.spotify.com/album/4UlGauD7ROb3YbVOFMgW5u'},
#  'genres': [],
#  'href': 'https://api.spotify.com/v1/albums/4UlGauD7ROb3YbVOFMgW5u',
#  'id': '4UlGauD7ROb3YbVOFMgW5u',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b27333c6b920eabcf4c00d7a1093',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e0233c6b920eabcf4c00d7a1093',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d0000485133c6b920eabcf4c00d7a1093',
#    'width': 64}],
#  'label': 'Roc Nation / Rihanna',
#  'name': 'ANTI (Deluxe)',
#  'popularity': 83,
#  'release_date': '2016-01-28',
#  'release_date_precision': 'day',
#  'total_tracks': 16,
#  'tracks': {'href': 'https://api.spotify.com/v1/albums/4UlGauD7ROb3YbVOFMgW5u/tracks?offset=0&limit=50',
#   'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#       'href': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP',
#       'id': '7tYKF4w9nC0nq9CsPZTHyP',
#       'name': 'SZA',
#       'type': 'artist',
#       'uri': 'spotify:artist:7tYKF4w9nC0nq9CsPZTHyP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 161066,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6t90Z9XkdsHD8xMxro6KRP'},
#     'href': 'https://api.spotify.com/v1/tracks/6t90Z9XkdsHD8xMxro6KRP',
#     'id': '6t90Z9XkdsHD8xMxro6KRP',
#     'is_local': False,
#     'name': 'Consideration',
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6t90Z9XkdsHD8xMxro6KRP'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 72080,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6K4Co1NQyOnoFEJMkZHkln'},
#     'href': 'https://api.spotify.com/v1/tracks/6K4Co1NQyOnoFEJMkZHkln',
#     'id': '6K4Co1NQyOnoFEJMkZHkln',
#     'is_local': False,
#     'name': 'James Joint',
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:6K4Co1NQyOnoFEJMkZHkln'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 253080,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0UHB9METy4VCXNgkcGqHqS'},
#     'href': 'https://api.spotify.com/v1/tracks/0UHB9METy4VCXNgkcGqHqS',
#     'id': '0UHB9METy4VCXNgkcGqHqS',
#     'is_local': False,
#     'name': 'Kiss It Better',
#     'preview_url': None,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:0UHB9METy4VCXNgkcGqHqS'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 219320,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/72TFWvU3wUYdUuxejTTIzt'},
#     'href': 'https://api.spotify.com/v1/tracks/72TFWvU3wUYdUuxejTTIzt',
#     'id': '72TFWvU3wUYdUuxejTTIzt',
#     'is_local': False,
#     'name': 'Work',
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:72TFWvU3wUYdUuxejTTIzt'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 186466,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4mCf3vQf7z0Yseo0RxAi3V'},
#     'href': 'https://api.spotify.com/v1/tracks/4mCf3vQf7z0Yseo0RxAi3V',
#     'id': '4mCf3vQf7z0Yseo0RxAi3V',
#     'is_local': False,
#     'name': 'Desperado',
#     'preview_url': None,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:4mCf3vQf7z0Yseo0RxAi3V'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 235586,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3HQcsqRjRdruUjkbDSgmVF'},
#     'href': 'https://api.spotify.com/v1/tracks/3HQcsqRjRdruUjkbDSgmVF',
#     'id': '3HQcsqRjRdruUjkbDSgmVF',
#     'is_local': False,
#     'name': 'Woo',
#     'preview_url': None,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:3HQcsqRjRdruUjkbDSgmVF'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 191600,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4pAl7FkDMNBsjykPXo91B3'},
#     'href': 'https://api.spotify.com/v1/tracks/4pAl7FkDMNBsjykPXo91B3',
#     'id': '4pAl7FkDMNBsjykPXo91B3',
#     'is_local': False,
#     'name': 'Needed Me',
#     'preview_url': None,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:4pAl7FkDMNBsjykPXo91B3'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 133080,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7eDYNlBwRMeFOZHOZ95dZ1'},
#     'href': 'https://api.spotify.com/v1/tracks/7eDYNlBwRMeFOZHOZ95dZ1',
#     'id': '7eDYNlBwRMeFOZHOZ95dZ1',
#     'is_local': False,
#     'name': 'Yeah, I Said It',
#     'preview_url': None,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:7eDYNlBwRMeFOZHOZ95dZ1'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 397093,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6RtzmszGXs32TRhv5zTKNM'},
#     'href': 'https://api.spotify.com/v1/tracks/6RtzmszGXs32TRhv5zTKNM',
#     'id': '6RtzmszGXs32TRhv5zTKNM',
#     'is_local': False,
#     'name': 'Same Ol’ Mistakes',
#     'preview_url': None,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:6RtzmszGXs32TRhv5zTKNM'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 202506,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7Jd5LgnSRQElW6FsTWVPzE'},
#     'href': 'https://api.spotify.com/v1/tracks/7Jd5LgnSRQElW6FsTWVPzE',
#     'id': '7Jd5LgnSRQElW6FsTWVPzE',
#     'is_local': False,
#     'name': 'Never Ending',
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:7Jd5LgnSRQElW6FsTWVPzE'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 224000,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5oO3drDxtziYU2H1X23ZIp'},
#     'href': 'https://api.spotify.com/v1/tracks/5oO3drDxtziYU2H1X23ZIp',
#     'id': '5oO3drDxtziYU2H1X23ZIp',
#     'is_local': False,
#     'name': 'Love On The Brain',
#     'preview_url': None,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:5oO3drDxtziYU2H1X23ZIp'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 120626,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1KnJwhZU3DIBe54Q4HPpIl'},
#     'href': 'https://api.spotify.com/v1/tracks/1KnJwhZU3DIBe54Q4HPpIl',
#     'id': '1KnJwhZU3DIBe54Q4HPpIl',
#     'is_local': False,
#     'name': 'Higher',
#     'preview_url': None,
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:1KnJwhZU3DIBe54Q4HPpIl'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 223213,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6D2tzc8kRnZb7P1lNwMBLH'},
#     'href': 'https://api.spotify.com/v1/tracks/6D2tzc8kRnZb7P1lNwMBLH',
#     'id': '6D2tzc8kRnZb7P1lNwMBLH',
#     'is_local': False,
#     'name': 'Close To You',
#     'preview_url': None,
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:6D2tzc8kRnZb7P1lNwMBLH'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 88493,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5LJz7kmFhLqB53tmVWxig5'},
#     'href': 'https://api.spotify.com/v1/tracks/5LJz7kmFhLqB53tmVWxig5',
#     'id': '5LJz7kmFhLqB53tmVWxig5',
#     'is_local': False,
#     'name': 'Goodnight Gotham',
#     'preview_url': None,
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:5LJz7kmFhLqB53tmVWxig5'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 144226,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4UTizOdGljPIIbXtoXycAd'},
#     'href': 'https://api.spotify.com/v1/tracks/4UTizOdGljPIIbXtoXycAd',
#     'id': '4UTizOdGljPIIbXtoXycAd',
#     'is_local': False,
#     'name': 'Pose',
#     'preview_url': None,
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:4UTizOdGljPIIbXtoXycAd'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 206400,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7BiELrM90hRxpozaIXbsLw'},
#     'href': 'https://api.spotify.com/v1/tracks/7BiELrM90hRxpozaIXbsLw',
#     'id': '7BiELrM90hRxpozaIXbsLw',
#     'is_local': False,
#     'name': 'Sex With Me',
#     'preview_url': None,
#     'track_number': 16,
#     'type': 'track',
#     'uri': 'spotify:track:7BiELrM90hRxpozaIXbsLw'}],
#   'limit': 50,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 16},
#  'type': 'album',
#  'uri': 'spotify:album:4UlGauD7ROb3YbVOFMgW5u'}

# %%
#spotify.search(query="Work", operator='NOT', operator_query='it',search_type="track")
